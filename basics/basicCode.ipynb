# %%
from deepeval import evaluate
from deepeval.metrics import ExactMatchMetric
from deepeval.test_case import LLMTestCase


firstTest = LLMTestCase(
    input="what is capital of india?",
    expected_output="Delhi",
    actual_output="Delhi"

)
    
evaluate([firstTest], metrics= [ExactMatchMetric()])
# Out:
# ✨ You're running DeepEval's latest Exact Match Metric! (using None, strict=False, async_mode=True)...
# c:\DeepEvalTutorial\venv\Lib\site-packages\rich\live.py:260: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
#
# Metrics Summary
#
#   - ✅ Exact Match (score: 1.0, threshold: 1.0, strict: False, evaluation model: None, reason: The actual and expected outputs are exact matches., error: None)
#
# For test case:
#
#   - input: what is capital of india?
#   - actual output: Delhi
#   - expected output: Delhi
#   - context: None
#   - retrieval context: None
#
# ...
#
# Overall Metric Pass Rates
#
# Exact Match: 100.00% pass rate
#
# ...

# %% [markdown]
# LLM

# %%
import deepeval


# !deepeval set-ollama --model llama3
# Out:
# 🙌 Congratulations! You're now using a local Ollama model `llama3` for all
# evals that require an LLM.

# %%
import deepeval
import os

from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("CONFIDENT_AI_API_KEY")

deepeval.login(api_key=api_key)
# Out:
# confident_us_proj_KE+l6DfPiF2maziKc6lQVel8ZYG1LHXUPX1pF2zkQE4=
# 🎉🥳 Congratulations! You've successfully logged in! 🙌

# %%
from deepeval import evaluate
from deepeval.metrics import AnswerRelevancyMetric, ExactMatchMetric
from deepeval.test_case import LLMTestCase
from dotenv import find_dotenv, load_dotenv
from deepeval.evaluate import AsyncConfig 
from deepeval.models import OllamaModel
import os
load_dotenv(find_dotenv())
ollama_mode=OllamaModel(model=os.getenv("MODEL"), base_url=os.getenv("BASE_URL"))
firstTest = LLMTestCase(
    input="what is capital of india?",
    expected_output="Delhi",
    actual_output="Delhi"

)
    
evaluate([firstTest], metrics= [AnswerRelevancyMetric(model=ollama_mode)],
         async_config=AsyncConfig(run_async=False)
         )
# Out:
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using llama3 (Ollama), strict=False,
# async_mode=False)...
# c:\DeepEvalTutorial\venv\Lib\site-packages\rich\live.py:260: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: llama3 (Ollama), reason: The score is 1.00 because the answer directly addresses the question about the capital of India, making it highly relevant., error: None)
#
# For test case:
#
#   - input: what is capital of india?
#   - actual output: Delhi
#   - expected output: Delhi
#   - context: None
#   - retrieval context: None
#
# ...
#
# Overall Metric Pass Rates
#
# Answer Relevancy: 100.00% pass rate
#
# ...
# ⚠ WARNING: No hyperparameters logged.
# ...
